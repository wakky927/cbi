# %%
from matplotlib import pyplot as plt
import numpy as np

from modules import calib

# %%
DIR = "gx_32_gy_32_t_32_s_64_th_70/"

# %%
ave_dx = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_500_1_dx.csv", delimiter=',')))
ave_dy = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_500_1_dy.csv", delimiter=',')))

# %%
width, height = 739, 693
n = 32

x, y = np.meshgrid(np.linspace(693, -46, n, dtype="int"), np.linspace(0, height, n, dtype="int"))
x = calib.px2mm(x)
y = calib.px2mm(y)

fig, ax = plt.subplots(figsize=(36, 30))

# ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel("$r$ [mm]", fontsize=100)
plt.ylabel("$z$ [mm]", fontsize=100)
plt.xticks(fontsize=100)
plt.yticks(fontsize=100)
c = np.sqrt(ave_dx**2 + ave_dy**2)

ave_dx /= c
ave_dy /= c

x = x[:, :-2]
y = y[:, :-2]
ave_dx = ave_dx[:, :-2]
ave_dy = ave_dy[:, :-2]
c = c[:, :-2]

im = ax.quiver(x, y, -ave_dx, ave_dy, c, cmap="jet", scale_units='xy', scale=0.12, width=0.0045)

pp = fig.colorbar(im)
for t in pp.ax.get_yticklabels():
    t.set_fontsize(100)
pp.set_label('$\sqrt{{u_r}^2+{u_z}^2}$ [mm/s]', fontsize=100, color="#ffffff")
pp.ax.tick_params(axis='y', colors="#ffffff")
im.set_clim(0, 120)
plt.savefig(DIR + "500_500_1_dx_dy.png", dpi=300)

# %%
ave_dx = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_500_2_dx.csv", delimiter=',')))
ave_dy = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_500_2_dy.csv", delimiter=',')))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13104/1826558258.py in <module>
# ----> 1 ave_dx = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_500_2_dx.csv", delimiter=',')))
#       2 ave_dy = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_500_2_dy.csv", delimiter=',')))
#
# ~\anaconda3\envs\cbi_venv\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1065             fname = os_fspath(fname)
#    1066         if _is_string_like(fname):
# -> 1067             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1068             fencoding = getattr(fh, 'encoding', 'latin1')
#    1069             fh = iter(fh)
#
# ~\anaconda3\envs\cbi_venv\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     191
#     192     ds = DataSource(destpath)
# --> 193     return ds.open(path, mode, encoding=encoding, newline=newline)
#     194
#     195
#
# ~\anaconda3\envs\cbi_venv\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     531                                       encoding=encoding, newline=newline)
#     532         else:
# --> 533             raise IOError("%s not found." % path)
#     534
#     535
#
# OSError: gx_32_gy_32_t_32_s_64_th_70/500_500_2_dx.csv not found.

# %%
width, height = 739, 693
n = 32

x, y = np.meshgrid(np.linspace(693, -46, n, dtype="int"), np.linspace(0, height, n, dtype="int"))
x = calib.px2mm(x)
y = calib.px2mm(y)

fig, ax = plt.subplots(figsize=(36, 30))
plt.xlabel("$r$ [mm]", fontsize=100)
plt.ylabel("$h$ [mm]", fontsize=100)
plt.xticks(fontsize=100)
plt.yticks(fontsize=100)
c = np.sqrt(ave_dx**2 + ave_dy**2)

ave_dx /= c
ave_dy /= c

x = x[:, :-2]
y = y[:, :-2]
ave_dx = ave_dx[:, :-2]
ave_dy = ave_dy[:, :-2]
c = c[:, :-2]

im = ax.quiver(x, y, -ave_dx, ave_dy, c, cmap="jet", scale_units='xy', scale=0.12, width=0.0045)

pp = fig.colorbar(im)
for t in pp.ax.get_yticklabels():
    t.set_fontsize(100)
pp.set_label('$\sqrt{u^2+v^2}$ [mm/s]', fontsize=100)
im.set_clim(0, 120)
plt.savefig(DIR + "500_500_2_dx_dy.png", dpi=300)

# %%
ave_dx = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_500_3_dx.csv", delimiter=',')))
ave_dy = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_500_3_dy.csv", delimiter=',')))

# %%
width, height = 739, 693
n = 32

x, y = np.meshgrid(np.linspace(693, -46, n, dtype="int"), np.linspace(0, height, n, dtype="int"))
x = calib.px2mm(x)
y = calib.px2mm(y)

fig, ax = plt.subplots(figsize=(36, 30))
plt.xlabel("$r$ [mm]", fontsize=100)
plt.ylabel("$h$ [mm]", fontsize=100)
plt.xticks(fontsize=100)
plt.yticks(fontsize=100)
c = np.sqrt(ave_dx**2 + ave_dy**2)

ave_dx /= c
ave_dy /= c

x = x[:, :-2]
y = y[:, :-2]
ave_dx = ave_dx[:, :-2]
ave_dy = ave_dy[:, :-2]
c = c[:, :-2]

im = ax.quiver(x, y, -ave_dx, ave_dy, c, cmap="jet", scale_units='xy', scale=0.12, width=0.0045)

pp = fig.colorbar(im)
for t in pp.ax.get_yticklabels():
    t.set_fontsize(100)
pp.set_label('$\sqrt{u^2+v^2}$ [mm/s]', fontsize=100)
im.set_clim(0, 120)
plt.savefig(DIR + "500_500_3_dx_dy.png", dpi=300)

# %%
ave_dx = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_1000_1_dx.csv", delimiter=',')))
ave_dy = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_1000_1_dy.csv", delimiter=',')))

# %%
width, height = 739, 693
n = 32

x, y = np.meshgrid(np.linspace(693, -46, n, dtype="int"), np.linspace(0, height, n, dtype="int"))
x = calib.px2mm(x)
y = calib.px2mm(y)

fig, ax = plt.subplots(figsize=(36, 30))
plt.xlabel("$r$ [mm]", fontsize=100)
plt.ylabel("$h$ [mm]", fontsize=100)
plt.xticks(fontsize=100)
plt.yticks(fontsize=100)
c = np.sqrt(ave_dx**2 + ave_dy**2)

ave_dx /= c
ave_dy /= c

x = x[:, :-2]
y = y[:, :-2]
ave_dx = ave_dx[:, :-2]
ave_dy = ave_dy[:, :-2]
c = c[:, :-2]

im = ax.quiver(x, y, -ave_dx, ave_dy, c, cmap="jet", scale_units='xy', scale=0.12, width=0.0045)

pp = fig.colorbar(im)
for t in pp.ax.get_yticklabels():
    t.set_fontsize(100)
pp.set_label('$\sqrt{u^2+v^2}$ [mm/s]', fontsize=100)
im.set_clim(0, 120)
plt.savefig(DIR + "500_1000_1_dx_dy.png", dpi=300)

# %%
ave_dx = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_1000_2_dx.csv", delimiter=',')))
ave_dy = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_1000_2_dy.csv", delimiter=',')))

# %%
width, height = 739, 693
n = 32

x, y = np.meshgrid(np.linspace(693, -46, n, dtype="int"), np.linspace(0, height, n, dtype="int"))
x = calib.px2mm(x)
y = calib.px2mm(y)

fig, ax = plt.subplots(figsize=(36, 30))
plt.xlabel("$r$ [mm]", fontsize=100)
plt.ylabel("$h$ [mm]", fontsize=100)
plt.xticks(fontsize=100)
plt.yticks(fontsize=100)
c = np.sqrt(ave_dx**2 + ave_dy**2)

ave_dx /= c
ave_dy /= c

x = x[:, :-2]
y = y[:, :-2]
ave_dx = ave_dx[:, :-2]
ave_dy = ave_dy[:, :-2]
c = c[:, :-2]

im = ax.quiver(x, y, -ave_dx, ave_dy, c, cmap="jet", scale_units='xy', scale=0.12, width=0.0045)

pp = fig.colorbar(im)
for t in pp.ax.get_yticklabels():
    t.set_fontsize(100)
pp.set_label('$\sqrt{u^2+v^2}$ [mm/s]', fontsize=100)
im.set_clim(0, 120)
plt.savefig(DIR + "500_1000_2_dx_dy.png", dpi=300)

# %%
ave_dx = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_1000_3_dx.csv", delimiter=',')))
ave_dy = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_1000_3_dy.csv", delimiter=',')))

# %%
width, height = 739, 693
n = 32

x, y = np.meshgrid(np.linspace(693, -46, n, dtype="int"), np.linspace(0, height, n, dtype="int"))
x = calib.px2mm(x)
y = calib.px2mm(y)

fig, ax = plt.subplots(figsize=(36, 30))
plt.xlabel("$r$ [mm]", fontsize=100)
plt.ylabel("$h$ [mm]", fontsize=100)
plt.xticks(fontsize=100)
plt.yticks(fontsize=100)
c = np.sqrt(ave_dx**2 + ave_dy**2)

ave_dx /= c
ave_dy /= c

x = x[:, :-2]
y = y[:, :-2]
ave_dx = ave_dx[:, :-2]
ave_dy = ave_dy[:, :-2]
c = c[:, :-2]

im = ax.quiver(x, y, -ave_dx, ave_dy, c, cmap="jet", scale_units='xy', scale=0.12, width=0.0045)

pp = fig.colorbar(im)
for t in pp.ax.get_yticklabels():
    t.set_fontsize(100)
pp.set_label('$\sqrt{u^2+v^2}$ [mm/s]', fontsize=100)
im.set_clim(0, 120)
plt.savefig(DIR + "500_1000_3_dx_dy.png", dpi=300)

# %%
ave_dx = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_1500_1_dx.csv", delimiter=',')))
ave_dy = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_1500_1_dy.csv", delimiter=',')))

# %%
width, height = 739, 693
n = 32

x, y = np.meshgrid(np.linspace(693, -46, n, dtype="int"), np.linspace(0, height, n, dtype="int"))
x = calib.px2mm(x)
y = calib.px2mm(y)

fig, ax = plt.subplots(figsize=(36, 30))
plt.xlabel("$r$ [mm]", fontsize=100)
plt.ylabel("$h$ [mm]", fontsize=100)
plt.xticks(fontsize=100)
plt.yticks(fontsize=100)
c = np.sqrt(ave_dx**2 + ave_dy**2)

ave_dx /= c
ave_dy /= c

x = x[:, :-2]
y = y[:, :-2]
ave_dx = ave_dx[:, :-2]
ave_dy = ave_dy[:, :-2]
c = c[:, :-2]

im = ax.quiver(x, y, -ave_dx, ave_dy, c, cmap="jet", scale_units='xy', scale=0.12, width=0.0045)

pp = fig.colorbar(im)
for t in pp.ax.get_yticklabels():
    t.set_fontsize(100)
pp.set_label('$\sqrt{u^2+v^2}$ [mm/s]', fontsize=100)
im.set_clim(0, 120)
plt.savefig(DIR + "500_1500_1_dx_dy.png", dpi=300)

# %%
ave_dx = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_1500_2_dx.csv", delimiter=',')))
ave_dy = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_1500_2_dy.csv", delimiter=',')))

# %%
width, height = 739, 693
n = 32

x, y = np.meshgrid(np.linspace(693, -46, n, dtype="int"), np.linspace(0, height, n, dtype="int"))
x = calib.px2mm(x)
y = calib.px2mm(y)

fig, ax = plt.subplots(figsize=(36, 30))
plt.xlabel("$r$ [mm]", fontsize=100)
plt.ylabel("$h$ [mm]", fontsize=100)
plt.xticks(fontsize=100)
plt.yticks(fontsize=100)
c = np.sqrt(ave_dx**2 + ave_dy**2)

ave_dx /= c
ave_dy /= c

x = x[:, :-2]
y = y[:, :-2]
ave_dx = ave_dx[:, :-2]
ave_dy = ave_dy[:, :-2]
c = c[:, :-2]

im = ax.quiver(x, y, -ave_dx, ave_dy, c, cmap="jet", scale_units='xy', scale=0.12, width=0.0045)

pp = fig.colorbar(im)
for t in pp.ax.get_yticklabels():
    t.set_fontsize(100)
pp.set_label('$\sqrt{u^2+v^2}$ [mm/s]', fontsize=100)
im.set_clim(0, 120)
plt.savefig(DIR + "500_1500_2_dx_dy.png", dpi=300)

# %%
ave_dx = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_1500_3_dx.csv", delimiter=',')))
ave_dy = calib.f2s(calib.px2mm(np.loadtxt(DIR + "500_1500_3_dy.csv", delimiter=',')))

# %%
width, height = 739, 693
n = 32

x, y = np.meshgrid(np.linspace(693, -46, n, dtype="int"), np.linspace(0, height, n, dtype="int"))
x = calib.px2mm(x)
y = calib.px2mm(y)

fig, ax = plt.subplots(figsize=(36, 30))
plt.xlabel("$r$ [mm]", fontsize=100)
plt.ylabel("$h$ [mm]", fontsize=100)
plt.xticks(fontsize=100)
plt.yticks(fontsize=100)
c = np.sqrt(ave_dx**2 + ave_dy**2)

ave_dx /= c
ave_dy /= c

x = x[:, :-2]
y = y[:, :-2]
ave_dx = ave_dx[:, :-2]
ave_dy = ave_dy[:, :-2]
c = c[:, :-2]

im = ax.quiver(x, y, -ave_dx, ave_dy, c, cmap="jet", scale_units='xy', scale=0.12, width=0.0045)

pp = fig.colorbar(im)
for t in pp.ax.get_yticklabels():
    t.set_fontsize(100)
pp.set_label('$\sqrt{u^2+v^2}$ [mm/s]', fontsize=100)
im.set_clim(0, 120)
plt.savefig(DIR + "500_1500_3_dx_dy.png", dpi=300)

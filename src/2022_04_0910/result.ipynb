# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
import pickle

# %%
res1_l_09 = pickle.load(open("result_09/light/res1.pickle", 'rb'))
res2_l_09 = pickle.load(open("result_09/light/res2.pickle", 'rb'))
res3_l_09 = pickle.load(open("result_09/light/res3.pickle", 'rb'))
res15_l_09 = pickle.load(open("result_09/light/res15.pickle", 'rb'))
res25_l_09 = pickle.load(open("result_09/light/res25.pickle", 'rb'))

# %%
res1_d_09 = pickle.load(open("result_09/dark/res1.pickle", 'rb'))
res2_d_09 = pickle.load(open("result_09/dark/res2.pickle", 'rb'))
res3_d_09 = pickle.load(open("result_09/dark/res3.pickle", 'rb'))
res15_d_09 = pickle.load(open("result_09/dark/res15.pickle", 'rb'))
res25_d_09 = pickle.load(open("result_09/dark/res25.pickle", 'rb'))

# %%
r_ur_ut_in_1_l_09 = pickle.load(open("result_09/light/r_ur_ut_in_1.pickle", 'rb'))
r_ur_ut_in_2_l_09 = pickle.load(open("result_09/light/r_ur_ut_in_2.pickle", 'rb'))
r_ur_ut_in_3_l_09 = pickle.load(open("result_09/light/r_ur_ut_in_3.pickle", 'rb'))
r_ur_ut_in_15_l_09 = pickle.load(open("result_09/light/r_ur_ut_in_15.pickle", 'rb'))
r_ur_ut_in_25_l_09 = pickle.load(open("result_09/light/r_ur_ut_in_25.pickle", 'rb'))

# %%
r_ur_ut_in_1_d_09 = pickle.load(open("result_09/dark/r_ur_ut_in_1.pickle", 'rb'))
r_ur_ut_in_2_d_09 = pickle.load(open("result_09/dark/r_ur_ut_in_2.pickle", 'rb'))
r_ur_ut_in_3_d_09 = pickle.load(open("result_09/dark/r_ur_ut_in_3.pickle", 'rb'))
r_ur_ut_in_15_d_09 = pickle.load(open("result_09/dark/r_ur_ut_in_15.pickle", 'rb'))
r_ur_ut_in_25_d_09 = pickle.load(open("result_09/dark/r_ur_ut_in_25.pickle", 'rb'))

# %%
r_ur_urErr_1_l_09 = pickle.load(open("result_09/light/r_ur_urErr_1.pickle", 'rb'))
r_ur_urErr_2_l_09 = pickle.load(open("result_09/light/r_ur_urErr_2.pickle", 'rb'))
r_ur_urErr_3_l_09 = pickle.load(open("result_09/light/r_ur_urErr_3.pickle", 'rb'))
r_ur_urErr_15_l_09 = pickle.load(open("result_09/light/r_ur_urErr_15.pickle", 'rb'))
r_ur_urErr_25_l_09 = pickle.load(open("result_09/light/r_ur_urErr_25.pickle", 'rb'))

# %%
r_ur_urErr_1_d_09 = pickle.load(open("result_09/dark/r_ur_urErr_1.pickle", 'rb'))
r_ur_urErr_2_d_09 = pickle.load(open("result_09/dark/r_ur_urErr_2.pickle", 'rb'))
r_ur_urErr_3_d_09 = pickle.load(open("result_09/dark/r_ur_urErr_3.pickle", 'rb'))
r_ur_urErr_15_d_09 = pickle.load(open("result_09/dark/r_ur_urErr_15.pickle", 'rb'))
r_ur_urErr_25_d_09 = pickle.load(open("result_09/dark/r_ur_urErr_25.pickle", 'rb'))

# %%
r_ut_utErr_1_l_09 = pickle.load(open("result_09/light/r_ut_utErr_1.pickle", 'rb'))
r_ut_utErr_2_l_09 = pickle.load(open("result_09/light/r_ut_utErr_2.pickle", 'rb'))
r_ut_utErr_3_l_09 = pickle.load(open("result_09/light/r_ut_utErr_3.pickle", 'rb'))
r_ut_utErr_15_l_09 = pickle.load(open("result_09/light/r_ut_utErr_15.pickle", 'rb'))
r_ut_utErr_25_l_09 = pickle.load(open("result_09/light/r_ut_utErr_25.pickle", 'rb'))

# %%
r_ut_utErr_1_d_09 = pickle.load(open("result_09/dark/r_ut_utErr_1.pickle", 'rb'))
r_ut_utErr_2_d_09 = pickle.load(open("result_09/dark/r_ut_utErr_2.pickle", 'rb'))
r_ut_utErr_3_d_09 = pickle.load(open("result_09/dark/r_ut_utErr_3.pickle", 'rb'))
r_ut_utErr_15_d_09 = pickle.load(open("result_09/dark/r_ut_utErr_15.pickle", 'rb'))
r_ut_utErr_25_d_09 = pickle.load(open("result_09/dark/r_ut_utErr_25.pickle", 'rb'))

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{r}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.scatter(res1_l_09[:, 0], res1_l_09[:, 2], alpha=1, zorder=1, c="cyan")
ax.scatter(res1_d_09[:, 0], res1_d_09[:, 2], alpha=1, zorder=1, c="#0067c0")

plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_09/imgs/raw_scatter.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{r}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.scatter(res1_l_09[:, 0], res1_l_09[:, 2], alpha=1, zorder=1, c="cyan")
ax.scatter(res1_d_09[:, 0], res1_d_09[:, 2], alpha=1, zorder=1, c="#0067c0")

ax.scatter(r_ur_ut_in_1_l_09[:, 0], r_ur_ut_in_1_l_09[:, 1], alpha=1, zorder=1, c="yellow")
ax.scatter(r_ur_ut_in_1_d_09[:, 0], r_ur_ut_in_1_d_09[:, 1], alpha=1, zorder=1, c="orange")

plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_09/imgs/raw_scatter_q.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{\theta}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.scatter(res1_l_09[:, 0], res1_l_09[:, 3], alpha=1, zorder=1, c="magenta")
ax.scatter(res1_d_09[:, 0], res1_d_09[:, 3], alpha=1, zorder=1, c="#ed1a3d")

plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_09/imgs/raw_scatter2.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{\theta}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.scatter(res1_l_09[:, 0], res1_l_09[:, 3], alpha=1, zorder=1, c="magenta")
ax.scatter(res1_d_09[:, 0], res1_d_09[:, 3], alpha=1, zorder=1, c="#ed1a3d")

ax.scatter(r_ur_ut_in_1_l_09[:, 0], r_ur_ut_in_1_l_09[:, 2], alpha=1, zorder=1, c="yellow")
ax.scatter(r_ur_ut_in_1_d_09[:, 0], r_ur_ut_in_1_d_09[:, 2], alpha=1, zorder=1, c="orange")

plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_09/imgs/raw_scatter2_q.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{r}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-15, 265)

ax.errorbar(r_ur_urErr_1_l_09[:, 0]/10, r_ur_urErr_1_l_09[:, 1], yerr=r_ur_urErr_1_l_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#0067c0', markeredgecolor="#0067c0", color='#0067c0', label=r"CBI: $\bar{Q}=1.0$ L/min")
ax.errorbar(r_ur_urErr_15_l_09[:, 0]/10, r_ur_urErr_15_l_09[:, 1], yerr=r_ur_urErr_15_l_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#00ae95', markeredgecolor="#00ae95", color='#00ae95', label=r"CBI: $\bar{Q}=1.5$ L/min")
ax.errorbar(r_ur_urErr_2_l_09[:, 0]/10, r_ur_urErr_2_l_09[:, 1], yerr=r_ur_urErr_2_l_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#008000', markeredgecolor="#008000", color='#008000', label=r"CBI: $\bar{Q}=2.0$ L/min")
ax.errorbar(r_ur_urErr_25_l_09[:, 0]/10, r_ur_urErr_25_l_09[:, 1], yerr=r_ur_urErr_25_l_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='orange', markeredgecolor="orange", color='orange', label=r"CBI: $\bar{Q}=2.5$ L/min")
ax.errorbar(r_ur_urErr_3_l_09[:, 0]/10, r_ur_urErr_3_l_09[:, 1], yerr=r_ur_urErr_3_l_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#ed1a3d', markeredgecolor="#ed1a3d", color='#ed1a3d', label=r"CBI: $\bar{Q}=3.0$ L/min")

ax.errorbar(r_ur_urErr_1_d_09[:, 0]/10, r_ur_urErr_1_d_09[:, 1], yerr=r_ur_urErr_1_d_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#0067c0', markeredgecolor="#0067c0", color='#0067c0')
ax.errorbar(r_ur_urErr_15_d_09[:, 0]/10, r_ur_urErr_15_d_09[:, 1], yerr=r_ur_urErr_15_d_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#00ae95', markeredgecolor="#00ae95", color='#00ae95')
ax.errorbar(r_ur_urErr_2_d_09[:, 0]/10, r_ur_urErr_2_d_09[:, 1], yerr=r_ur_urErr_2_d_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#008000', markeredgecolor="#008000", color='#008000')
ax.errorbar(r_ur_urErr_25_d_09[:, 0]/10, r_ur_urErr_25_d_09[:, 1], yerr=r_ur_urErr_25_d_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='orange', markeredgecolor="orange", color='orange')
ax.errorbar(r_ur_urErr_3_d_09[:, 0]/10, r_ur_urErr_3_d_09[:, 1], yerr=r_ur_urErr_3_d_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#ed1a3d', markeredgecolor="#ed1a3d", color='#ed1a3d')

plt.legend(fontsize=24, facecolor='#333333', labelcolor='#ffffff', framealpha=1)
plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_09/imgs/scatter_e.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{r}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-15, 265)

ax.scatter(r_ur_urErr_1_l_09[:, 0]/10, r_ur_urErr_1_l_09[:, 1], marker='o', s=100, color='#0067c0', label=r"CBI: $\bar{Q}=1.0$ L/min")
ax.scatter(r_ur_urErr_15_l_09[:, 0]/10, r_ur_urErr_15_l_09[:, 1], marker='o', s=100, color='#00ae95', label=r"CBI: $\bar{Q}=1.5$ L/min")
ax.scatter(r_ur_urErr_2_l_09[:, 0]/10, r_ur_urErr_2_l_09[:, 1], marker='o', s=100, color='#008000', label=r"CBI: $\bar{Q}=2.0$ L/min")
ax.scatter(r_ur_urErr_25_l_09[:, 0]/10, r_ur_urErr_25_l_09[:, 1], marker='o', s=100, color='orange', label=r"CBI: $\bar{Q}=2.5$ L/min")
ax.scatter(r_ur_urErr_3_l_09[:, 0]/10, r_ur_urErr_3_l_09[:, 1], marker='o', s=100, color='#ed1a3d', label=r"CBI: $\bar{Q}=3.0$ L/min")

ax.scatter(r_ur_urErr_1_d_09[:, 0]/10, r_ur_urErr_1_d_09[:, 1], marker='o', s=100, color='#0067c0')
ax.scatter(r_ur_urErr_15_d_09[:, 0]/10, r_ur_urErr_15_d_09[:, 1], marker='o', s=100, color='#00ae95')
ax.scatter(r_ur_urErr_2_d_09[:, 0]/10, r_ur_urErr_2_d_09[:, 1], marker='o', s=100, color='#008000')
ax.scatter(r_ur_urErr_25_d_09[:, 0]/10, r_ur_urErr_25_d_09[:, 1], marker='o', s=100, color='orange')
ax.scatter(r_ur_urErr_3_d_09[:, 0]/10, r_ur_urErr_3_d_09[:, 1], marker='o', s=100, color='#ed1a3d')

plt.legend(fontsize=24, facecolor='#333333', labelcolor='#ffffff', framealpha=1)
plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_09/imgs/scatter.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{\theta}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.errorbar(r_ut_utErr_1_l_09[:, 0]/10, r_ut_utErr_1_l_09[:, 1], yerr=r_ut_utErr_1_l_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#0067c0', markeredgecolor="#0067c0", color='#0067c0', label=r"CBI: $\bar{Q}=1.0$ L/min")
ax.errorbar(r_ut_utErr_15_l_09[:, 0]/10, r_ut_utErr_15_l_09[:, 1], yerr=r_ut_utErr_15_l_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#00ae95', markeredgecolor="#00ae95", color='#00ae95', label=r"CBI: $\bar{Q}=1.5$ L/min")
ax.errorbar(r_ut_utErr_2_l_09[:, 0]/10, r_ut_utErr_2_l_09[:, 1], yerr=r_ut_utErr_2_l_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#008000', markeredgecolor="#008000", color='#008000', label=r"CBI: $\bar{Q}=2.0$ L/min")
ax.errorbar(r_ut_utErr_25_l_09[:, 0]/10, r_ut_utErr_25_l_09[:, 1], yerr=r_ut_utErr_25_l_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='orange', markeredgecolor="orange", color='orange', label=r"CBI: $\bar{Q}=2.5$ L/min")
ax.errorbar(r_ut_utErr_3_l_09[:, 0]/10, r_ut_utErr_3_l_09[:, 1], yerr=r_ut_utErr_3_l_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#ed1a3d', markeredgecolor="#ed1a3d", color='#ed1a3d', label=r"CBI: $\bar{Q}=3.0$ L/min")

ax.errorbar(r_ut_utErr_1_d_09[:, 0]/10, r_ut_utErr_1_d_09[:, 1], yerr=r_ut_utErr_1_d_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#0067c0', markeredgecolor="#0067c0", color='#0067c0')
ax.errorbar(r_ut_utErr_15_d_09[:, 0]/10, r_ut_utErr_15_d_09[:, 1], yerr=r_ut_utErr_15_d_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#00ae95', markeredgecolor="#00ae95", color='#00ae95')
ax.errorbar(r_ut_utErr_2_d_09[:, 0]/10, r_ut_utErr_2_d_09[:, 1], yerr=r_ut_utErr_2_d_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#008000', markeredgecolor="#008000", color='#008000')
ax.errorbar(r_ut_utErr_25_d_09[:, 0]/10, r_ut_utErr_25_d_09[:, 1], yerr=r_ut_utErr_25_d_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='orange', markeredgecolor="orange", color='orange')
ax.errorbar(r_ut_utErr_3_d_09[:, 0]/10, r_ut_utErr_3_d_09[:, 1], yerr=r_ut_utErr_3_d_09[:, 2], capsize=10, fmt='o', markersize=10, ecolor='#ed1a3d', markeredgecolor="#ed1a3d", color='#ed1a3d')

plt.legend(fontsize=24, facecolor='#333333', labelcolor='#ffffff', framealpha=1)
plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_09/imgs/scatter2_e.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{\theta}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.scatter(r_ut_utErr_1_l_09[:, 0]/10, r_ut_utErr_1_l_09[:, 1], marker='o', s=100, color='#0067c0', label=r"CBI: $\bar{Q}=1.0$ L/min")
ax.scatter(r_ut_utErr_15_l_09[:, 0]/10, r_ut_utErr_15_l_09[:, 1], marker='o', s=100, color='#00ae95', label=r"CBI: $\bar{Q}=1.5$ L/min")
ax.scatter(r_ut_utErr_2_l_09[:, 0]/10, r_ut_utErr_2_l_09[:, 1], marker='o', s=100, color='#008000', label=r"CBI: $\bar{Q}=2.0$ L/min")
ax.scatter(r_ut_utErr_25_l_09[:, 0]/10, r_ut_utErr_25_l_09[:, 1], marker='o', s=100, color='orange', label=r"CBI: $\bar{Q}=2.5$ L/min")
ax.scatter(r_ut_utErr_3_l_09[:, 0]/10, r_ut_utErr_3_l_09[:, 1], marker='o', s=100, color='#ed1a3d', label=r"CBI: $\bar{Q}=3.0$ L/min")

ax.scatter(r_ut_utErr_1_d_09[:, 0]/10, r_ut_utErr_1_d_09[:, 1], marker='o', s=100, color='#0067c0')
ax.scatter(r_ut_utErr_15_d_09[:, 0]/10, r_ut_utErr_15_d_09[:, 1], marker='o', s=100, color='#00ae95')
ax.scatter(r_ut_utErr_2_d_09[:, 0]/10, r_ut_utErr_2_d_09[:, 1], marker='o', s=100, color='#008000')
ax.scatter(r_ut_utErr_25_d_09[:, 0]/10, r_ut_utErr_25_d_09[:, 1], marker='o', s=100, color='orange')
ax.scatter(r_ut_utErr_3_d_09[:, 0]/10, r_ut_utErr_3_d_09[:, 1], marker='o', s=100, color='#ed1a3d')

plt.legend(fontsize=24, facecolor='#333333', labelcolor='#ffffff', framealpha=1)
plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_09/imgs/scatter2.png", dpi=80)

plt.show()

# %%
res1_l_10 = pickle.load(open("result_10/light/res1.pickle", 'rb'))
res2_l_10 = pickle.load(open("result_10/light/res2.pickle", 'rb'))
res3_l_10 = pickle.load(open("result_10/light/res3.pickle", 'rb'))

# %%
res1_d_10 = pickle.load(open("result_10/dark/res1.pickle", 'rb'))
res2_d_10 = pickle.load(open("result_10/dark/res2.pickle", 'rb'))
res3_d_10 = pickle.load(open("result_10/dark/res3.pickle", 'rb'))

# %%
r_ur_ut_in_1_l_10 = pickle.load(open("result_10/light/r_ur_ut_in_1.pickle", 'rb'))
r_ur_ut_in_2_l_10 = pickle.load(open("result_10/light/r_ur_ut_in_2.pickle", 'rb'))
r_ur_ut_in_3_l_10 = pickle.load(open("result_10/light/r_ur_ut_in_3.pickle", 'rb'))

# %%
r_ur_ut_in_1_d_10 = pickle.load(open("result_10/dark/r_ur_ut_in_1.pickle", 'rb'))
r_ur_ut_in_2_d_10 = pickle.load(open("result_10/dark/r_ur_ut_in_2.pickle", 'rb'))
r_ur_ut_in_3_d_10 = pickle.load(open("result_10/dark/r_ur_ut_in_3.pickle", 'rb'))

# %%
r_ur_urErr_1_l_10 = pickle.load(open("result_10/light/r_ur_urErr_1.pickle", 'rb'))
r_ur_urErr_2_l_10 = pickle.load(open("result_10/light/r_ur_urErr_2.pickle", 'rb'))
r_ur_urErr_3_l_10 = pickle.load(open("result_10/light/r_ur_urErr_3.pickle", 'rb'))

# %%
r_ur_urErr_1_d_10 = pickle.load(open("result_10/dark/r_ur_urErr_1.pickle", 'rb'))
r_ur_urErr_2_d_10 = pickle.load(open("result_10/dark/r_ur_urErr_2.pickle", 'rb'))
r_ur_urErr_3_d_10 = pickle.load(open("result_10/dark/r_ur_urErr_3.pickle", 'rb'))

# %%
r_ut_utErr_1_l_10 = pickle.load(open("result_10/light/r_ut_utErr_1.pickle", 'rb'))
r_ut_utErr_2_l_10 = pickle.load(open("result_10/light/r_ut_utErr_2.pickle", 'rb'))
r_ut_utErr_3_l_10 = pickle.load(open("result_10/light/r_ut_utErr_3.pickle", 'rb'))

# %%
r_ut_utErr_1_d_10 = pickle.load(open("result_10/dark/r_ut_utErr_1.pickle", 'rb'))
r_ut_utErr_2_d_10 = pickle.load(open("result_10/dark/r_ut_utErr_2.pickle", 'rb'))
r_ut_utErr_3_d_10 = pickle.load(open("result_10/dark/r_ut_utErr_3.pickle", 'rb'))

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{r}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.scatter(res1_l_10[:, 0], res1_l_10[:, 2], alpha=1, zorder=1, c="cyan")
ax.scatter(res1_d_10[:, 0], res1_d_10[:, 2], alpha=1, zorder=1, c="#0067c0")

plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_10/imgs/raw_scatter.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{r}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.scatter(res1_l_10[:, 0], res1_l_10[:, 2], alpha=1, zorder=1, c="cyan")
ax.scatter(res1_d_10[:, 0], res1_d_10[:, 2], alpha=1, zorder=1, c="#0067c0")

ax.scatter(r_ur_ut_in_1_l_10[:, 0], r_ur_ut_in_1_l_10[:, 1], alpha=1, zorder=1, c="yellow")
ax.scatter(r_ur_ut_in_1_d_10[:, 0], r_ur_ut_in_1_d_10[:, 1], alpha=1, zorder=1, c="orange")

plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_10/imgs/raw_scatter_q.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{\theta}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.scatter(res1_l_10[:, 0], res1_l_10[:, 3], alpha=1, zorder=1, c="magenta")
ax.scatter(res1_d_10[:, 0], res1_d_10[:, 3], alpha=1, zorder=1, c="#ed1a3d")

plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_10/imgs/raw_scatter2.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{\theta}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.scatter(res1_l_10[:, 0], res1_l_10[:, 3], alpha=1, zorder=1, c="magenta")
ax.scatter(res1_d_10[:, 0], res1_d_10[:, 3], alpha=1, zorder=1, c="#ed1a3d")

ax.scatter(r_ur_ut_in_1_l_10[:, 0], r_ur_ut_in_1_l_10[:, 2], alpha=1, zorder=1, c="yellow")
ax.scatter(r_ur_ut_in_1_d_10[:, 0], r_ur_ut_in_1_d_10[:, 2], alpha=1, zorder=1, c="orange")

plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_10/imgs/raw_scatter2_q.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{r}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-15, 265)

ax.errorbar(r_ur_urErr_1_l_10[:, 0]/10, r_ur_urErr_1_l_10[:, 1], yerr=r_ur_urErr_1_l_10[:, 2], capsize=10, fmt='s', markersize=10, ecolor='#0067c0', markeredgecolor="#0067c0", color='#0067c0', label=r"RBI: $\bar{Q}=1$ L/min")
ax.errorbar(r_ur_urErr_2_l_10[:, 0]/10, r_ur_urErr_2_l_10[:, 1], yerr=r_ur_urErr_2_l_10[:, 2], capsize=10, fmt='s', markersize=10, ecolor='#008000', markeredgecolor="#008000", color='#008000', label=r"RBI: $\bar{Q}=2$ L/min")
ax.errorbar(r_ur_urErr_3_l_10[:, 0]/10, r_ur_urErr_3_l_10[:, 1], yerr=r_ur_urErr_3_l_10[:, 2], capsize=10, fmt='s', markersize=10, ecolor='#ed1a3d', markeredgecolor="#ed1a3d", color='#ed1a3d', label=r"RBI: $\bar{Q}=3$ L/min")

ax.errorbar(r_ur_urErr_1_d_10[:, 0]/10, r_ur_urErr_1_d_10[:, 1], yerr=r_ur_urErr_1_d_10[:, 2], capsize=10, fmt='s', markersize=10, ecolor='#0067c0', markeredgecolor="#0067c0", color='#0067c0')
ax.errorbar(r_ur_urErr_2_d_10[:, 0]/10, r_ur_urErr_2_d_10[:, 1], yerr=r_ur_urErr_2_d_10[:, 2], capsize=10, fmt='s', markersize=10, ecolor='#008000', markeredgecolor="#008000", color='#008000')
ax.errorbar(r_ur_urErr_3_d_10[:, 0]/10, r_ur_urErr_3_d_10[:, 1], yerr=r_ur_urErr_3_d_10[:, 2], capsize=10, fmt='s', markersize=10, ecolor='#ed1a3d', markeredgecolor="#ed1a3d", color='#ed1a3d')

plt.legend(fontsize=24, facecolor='#333333', labelcolor='#ffffff', framealpha=1)
plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_10/imgs/scatter_e.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{r}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-15, 265)

ax.scatter(r_ur_urErr_1_l_10[:, 0]/10, r_ur_urErr_1_l_10[:, 1], marker='s', s=100, color='#0067c0', label=r"RBI: $\bar{Q}=1$ L/min")
ax.scatter(r_ur_urErr_2_l_10[:, 0]/10, r_ur_urErr_2_l_10[:, 1], marker='s', s=100, color='#008000', label=r"RBI: $\bar{Q}=2$ L/min")
ax.scatter(r_ur_urErr_3_l_10[:, 0]/10, r_ur_urErr_3_l_10[:, 1], marker='s', s=100, color='#ed1a3d', label=r"RBI: $\bar{Q}=3$ L/min")

ax.scatter(r_ur_urErr_1_d_10[:, 0]/10, r_ur_urErr_1_d_10[:, 1], marker='s', s=100, color='#0067c0')
ax.scatter(r_ur_urErr_2_d_10[:, 0]/10, r_ur_urErr_2_d_10[:, 1], marker='s', s=100, color='#008000')
ax.scatter(r_ur_urErr_3_d_10[:, 0]/10, r_ur_urErr_3_d_10[:, 1], marker='s', s=100, color='#ed1a3d')

plt.legend(fontsize=24, facecolor='#333333', labelcolor='#ffffff', framealpha=1)
plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_10/imgs/scatter.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{\theta}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.errorbar(r_ut_utErr_1_l_10[:, 0]/10, r_ut_utErr_1_l_10[:, 1], yerr=r_ut_utErr_1_l_10[:, 2], capsize=10, fmt='s', markersize=10, ecolor='#0067c0', markeredgecolor="#0067c0", color='#0067c0', label=r"RBI: $\bar{Q}=1$ L/min")
ax.errorbar(r_ut_utErr_2_l_10[:, 0]/10, r_ut_utErr_2_l_10[:, 1], yerr=r_ut_utErr_2_l_10[:, 2], capsize=10, fmt='s', markersize=10, ecolor='#008000', markeredgecolor="#008000", color='#008000', label=r"RBI: $\bar{Q}=2$ L/min")
ax.errorbar(r_ut_utErr_3_l_10[:, 0]/10, r_ut_utErr_3_l_10[:, 1], yerr=r_ut_utErr_3_l_10[:, 2], capsize=10, fmt='s', markersize=10, ecolor='#ed1a3d', markeredgecolor="#ed1a3d", color='#ed1a3d', label=r"RBI: $\bar{Q}=3$ L/min")

ax.errorbar(r_ut_utErr_1_d_10[:, 0]/10, r_ut_utErr_1_d_10[:, 1], yerr=r_ut_utErr_1_d_10[:, 2], capsize=10, fmt='s', markersize=10, ecolor='#0067c0', markeredgecolor="#0067c0", color='#0067c0')
ax.errorbar(r_ut_utErr_2_d_10[:, 0]/10, r_ut_utErr_2_d_10[:, 1], yerr=r_ut_utErr_2_d_10[:, 2], capsize=10, fmt='s', markersize=10, ecolor='#008000', markeredgecolor="#008000", color='#008000')
ax.errorbar(r_ut_utErr_3_d_10[:, 0]/10, r_ut_utErr_3_d_10[:, 1], yerr=r_ut_utErr_3_d_10[:, 2], capsize=10, fmt='s', markersize=10, ecolor='#ed1a3d', markeredgecolor="#ed1a3d", color='#ed1a3d')

plt.legend(fontsize=24, facecolor='#333333', labelcolor='#ffffff', framealpha=1)
plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_10/imgs/scatter2_e.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{\theta}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.scatter(r_ut_utErr_1_l_10[:, 0]/10, r_ut_utErr_1_l_10[:, 1], marker='o', s=100, color='#0067c0', label=r"RBI: $\bar{Q}=1$ L/min")
ax.scatter(r_ut_utErr_2_l_10[:, 0]/10, r_ut_utErr_2_l_10[:, 1], marker='o', s=100, color='#008000', label=r"RBI: $\bar{Q}=2$ L/min")
ax.scatter(r_ut_utErr_3_l_10[:, 0]/10, r_ut_utErr_3_l_10[:, 1], marker='o', s=100, color='#ed1a3d', label=r"RBI: $\bar{Q}=3$ L/min")

ax.scatter(r_ut_utErr_1_d_10[:, 0]/10, r_ut_utErr_1_d_10[:, 1], marker='o', s=100, color='#0067c0')
ax.scatter(r_ut_utErr_2_d_10[:, 0]/10, r_ut_utErr_2_d_10[:, 1], marker='o', s=100, color='#008000')
ax.scatter(r_ut_utErr_3_d_10[:, 0]/10, r_ut_utErr_3_d_10[:, 1], marker='o', s=100, color='#ed1a3d')

plt.legend(fontsize=24, facecolor='#333333', labelcolor='#ffffff', framealpha=1)
plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_10/imgs/scatter2.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{r}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-15, 265)

ax.scatter(r_ur_urErr_1_l_09[:, 0]/10, r_ur_urErr_1_l_09[:, 1], marker='o', s=100, color='#0067c0', label=r"CBI: $\bar{Q}=1.0$ L/min")
ax.scatter(r_ur_urErr_2_l_09[:, 0]/10, r_ur_urErr_2_l_09[:, 1], marker='o', s=100, color='#008000', label=r"CBI: $\bar{Q}=2.0$ L/min")
ax.scatter(r_ur_urErr_3_l_09[:, 0]/10, r_ur_urErr_3_l_09[:, 1], marker='o', s=100, color='#ed1a3d', label=r"CBI: $\bar{Q}=3.0$ L/min")

ax.scatter(r_ur_urErr_1_d_09[:, 0]/10, r_ur_urErr_1_d_09[:, 1], marker='o', s=100, color='#0067c0')
ax.scatter(r_ur_urErr_2_d_09[:, 0]/10, r_ur_urErr_2_d_09[:, 1], marker='o', s=100, color='#008000')
ax.scatter(r_ur_urErr_3_d_09[:, 0]/10, r_ur_urErr_3_d_09[:, 1], marker='o', s=100, color='#ed1a3d')

ax.scatter(r_ur_urErr_1_l_10[:, 0]/10, r_ur_urErr_1_l_10[:, 1], marker='s', s=100, color='#00ADB9', label=r"RBI: $\bar{Q}=1$ L/min")
ax.scatter(r_ur_urErr_2_l_10[:, 0]/10, r_ur_urErr_2_l_10[:, 1], marker='s', s=100, color='#F7EA00', label=r"RBI: $\bar{Q}=2$ L/min")
ax.scatter(r_ur_urErr_3_l_10[:, 0]/10, r_ur_urErr_3_l_10[:, 1], marker='s', s=100, color='#FF188A', label=r"RBI: $\bar{Q}=3$ L/min")

ax.scatter(r_ur_urErr_1_d_10[:, 0]/10, r_ur_urErr_1_d_10[:, 1], marker='s', s=100, color='#00ADB9')
ax.scatter(r_ur_urErr_2_d_10[:, 0]/10, r_ur_urErr_2_d_10[:, 1], marker='s', s=100, color='#F7EA00')
ax.scatter(r_ur_urErr_3_d_10[:, 0]/10, r_ur_urErr_3_d_10[:, 1], marker='s', s=100, color='#FF188A')

plt.legend(ncol=2, fontsize=24, facecolor='#333333', labelcolor='#ffffff', framealpha=1)
plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_0910/imgs/scatter.png", dpi=80)

plt.show()

# %%
fig, ax = plt.subplots(facecolor="#333333", figsize=(16, 10))

ax.set_facecolor('#333333')
ax.spines['top'].set_color('#ffffff')
ax.spines['bottom'].set_color('#ffffff')
ax.spines['left'].set_color('#ffffff')
ax.spines['right'].set_color('#ffffff')
ax.tick_params(axis='x', colors='#ffffff')
ax.tick_params(axis='y', colors='#ffffff')
ax.xaxis.label.set_color('#ffffff')
ax.yaxis.label.set_color('#ffffff')

plt.xlabel(r"$r$ [mm]", fontsize=32)
plt.ylabel(r"$u_{\theta}$ [mm/s]", fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.xlim(0, 350)
plt.ylim(-305, 305)

ax.scatter(r_ut_utErr_1_l_09[:, 0]/10, r_ut_utErr_1_l_09[:, 1], marker='o', s=100, color='#0067c0', label=r"CBI: $\bar{Q}=1.0$ L/min")
ax.scatter(r_ut_utErr_2_l_09[:, 0]/10, r_ut_utErr_2_l_09[:, 1], marker='o', s=100, color='#008000', label=r"CBI: $\bar{Q}=2.0$ L/min")
ax.scatter(r_ut_utErr_3_l_09[:, 0]/10, r_ut_utErr_3_l_09[:, 1], marker='o', s=100, color='#ed1a3d', label=r"CBI: $\bar{Q}=3.0$ L/min")

ax.scatter(r_ut_utErr_1_d_09[:, 0]/10, r_ut_utErr_1_d_09[:, 1], marker='o', s=100, color='#0067c0')
ax.scatter(r_ut_utErr_2_d_09[:, 0]/10, r_ut_utErr_2_d_09[:, 1], marker='o', s=100, color='#008000')
ax.scatter(r_ut_utErr_3_d_09[:, 0]/10, r_ut_utErr_3_d_09[:, 1], marker='o', s=100, color='#ed1a3d')

ax.scatter(r_ut_utErr_1_l_10[:, 0]/10, r_ut_utErr_1_l_10[:, 1], marker='s', s=100, color='#00ADB9', label=r"RBI: $\bar{Q}=1$ L/min")
ax.scatter(r_ut_utErr_2_l_10[:, 0]/10, r_ut_utErr_2_l_10[:, 1], marker='s', s=100, color='#F7EA00', label=r"RBI: $\bar{Q}=2$ L/min")
ax.scatter(r_ut_utErr_3_l_10[:, 0]/10, r_ut_utErr_3_l_10[:, 1], marker='s', s=100, color='#FF188A', label=r"RBI: $\bar{Q}=3$ L/min")

ax.scatter(r_ut_utErr_1_d_10[:, 0]/10, r_ut_utErr_1_d_10[:, 1], marker='s', s=100, color='#00ADB9')
ax.scatter(r_ut_utErr_2_d_10[:, 0]/10, r_ut_utErr_2_d_10[:, 1], marker='s', s=100, color='#F7EA00')
ax.scatter(r_ut_utErr_3_d_10[:, 0]/10, r_ut_utErr_3_d_10[:, 1], marker='s', s=100, color='#FF188A')

plt.legend(ncol=2, fontsize=24, facecolor='#333333', labelcolor='#ffffff', framealpha=1)
plt.grid()
ax.set_axisbelow(True)

fig.savefig("result_0910/imgs/scatter2.png", dpi=80)

plt.show()

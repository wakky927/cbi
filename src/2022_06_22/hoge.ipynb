# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

import pre

# %%
width, height = 15, 15
image = np.zeros((height, width), dtype=np.uint8)

# %%
sample_img = pre.gauss_circle(image.copy(), 2)

# %%
plt.imshow(sample_img)
plt.show()

# %%
# cv2.imwrite("gauss_circle_size_25_sd_5.bmp", sample_img)

# %%
img = cv2.imread("C001H001S0001000001.bmp", 0)

# %%
plt.imshow(img)
plt.show()

# %%
ji = pre.detect_tracer(img=img, tracer_im=sample_img, threshold=0.7)

# %%
img2 = np.zeros((img.shape[0], img.shape[1]), dtype=np.uint8)

for k in tqdm(range(len(ji[0]))):
    img2[ji[0][k]+width//2-1, ji[1][k]+height//2-1] = 255
# Out:
# 100%|██████████| 1321/1321 [00:00<00:00, 823524.91it/s]

# %%
plt.imshow(img2)
plt.show()

# %%
cv2.imwrite("test.bmp", img2)
# Out:
# True

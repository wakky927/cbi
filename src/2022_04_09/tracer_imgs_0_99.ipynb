# %%
import cv2
import matplotlib.pyplot as plt

# %%
DIR = "adj/"
FILE = "C001H001S0001001500.bmp"
OUT_DIR = "tracer_imgs_dark/"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)

# %%
im_tracer_0 = im_rgb[59:79, 265:285, :]
cv2.imwrite(OUT_DIR + "tracer_0.bmp", cv2.cvtColor(im_tracer_0, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_0)
plt.show()

# %%
im_tracer_1 = im_rgb[101:121, 262:282, :]
cv2.imwrite(OUT_DIR + "tracer_1.bmp", cv2.cvtColor(im_tracer_1, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_1)
plt.show()

# %%
im_tracer_2 = im_rgb[130:150, 203:223, :]
cv2.imwrite(OUT_DIR + "tracer_2.bmp", cv2.cvtColor(im_tracer_2, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_2)
plt.show()

# %%
im_tracer_3 = im_rgb[252:272, 155:175, :]
cv2.imwrite(OUT_DIR + "tracer_3.bmp", cv2.cvtColor(im_tracer_3, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_3)
plt.show()

# %%
im_tracer_4 = im_rgb[163:183, 320:340, :]
cv2.imwrite(OUT_DIR + "tracer_4.bmp", cv2.cvtColor(im_tracer_4, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_4)
plt.show()

# %%
im_tracer_5 = im_rgb[15:35, 833:853, :]
cv2.imwrite(OUT_DIR + "tracer_5.bmp", cv2.cvtColor(im_tracer_5, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_5)
plt.show()

# %%
im_tracer_6 = im_rgb[159:179, 598:618, :]
cv2.imwrite(OUT_DIR + "tracer_6.bmp", cv2.cvtColor(im_tracer_6, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_6)
plt.show()

# %%
im_tracer_7 = im_rgb[334:354, 855:875, :]
cv2.imwrite(OUT_DIR + "tracer_7.bmp", cv2.cvtColor(im_tracer_7, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_7)
plt.show()

# %%
im_tracer_8 = im_rgb[312:332, 874:894, :]
cv2.imwrite(OUT_DIR + "tracer_8.bmp", cv2.cvtColor(im_tracer_8, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_8)
plt.show()

# %%
im_tracer_9 = im_rgb[414:434, 893:913, :]
cv2.imwrite(OUT_DIR + "tracer_9.bmp", cv2.cvtColor(im_tracer_9, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_9)
plt.show()

# %%
im_tracer_10 = im_rgb[415:435, 911:931, :]
cv2.imwrite(OUT_DIR + "tracer_10.bmp", cv2.cvtColor(im_tracer_10, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_10)
plt.show()

# %%
im_tracer_11 = im_rgb[510:530, 929:949, :]
cv2.imwrite(OUT_DIR + "tracer_11.bmp", cv2.cvtColor(im_tracer_11, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_11)
plt.show()

# %%
im_tracer_12 = im_rgb[570:590, 897:917, :]
cv2.imwrite(OUT_DIR + "tracer_12.bmp", cv2.cvtColor(im_tracer_12, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_12)
plt.show()

# %%
im_tracer_13 = im_rgb[616:636, 936:956, :]
cv2.imwrite(OUT_DIR + "tracer_13.bmp", cv2.cvtColor(im_tracer_13, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_13)
plt.show()

# %%
im_tracer_14 = im_rgb[655:675, 908:928, :]
cv2.imwrite(OUT_DIR + "tracer_14.bmp", cv2.cvtColor(im_tracer_14, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_14)
plt.show()

# %%
im_tracer_15 = im_rgb[674:694, 967:987, :]
cv2.imwrite(OUT_DIR + "tracer_15.bmp", cv2.cvtColor(im_tracer_15, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_15)
plt.show()

# %%
DIR = "adj/"
FILE = "C001H001S0002000001.bmp"
OUT_DIR = "tracer_imgs_dark/"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)

# %%
im_tracer_16 = im_rgb[36:56, 100:120, :]
cv2.imwrite(OUT_DIR + "tracer_16.bmp", cv2.cvtColor(im_tracer_16, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_16)
plt.show()

# %%
im_tracer_17 = im_rgb[19:39, 213:233, :]
cv2.imwrite(OUT_DIR + "tracer_17.bmp", cv2.cvtColor(im_tracer_17, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_17)
plt.show()

# %%
im_tracer_18 = im_rgb[75:95, 36:56, :]
cv2.imwrite(OUT_DIR + "tracer_18.bmp", cv2.cvtColor(im_tracer_18, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_18)
plt.show()

# %%
im_tracer_19 = im_rgb[118:138, 39:59, :]
cv2.imwrite(OUT_DIR + "tracer_19.bmp", cv2.cvtColor(im_tracer_19, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_19)
plt.show()

# %%
im_tracer_20 = im_rgb[136:156, 47:67, :]
cv2.imwrite(OUT_DIR + "tracer_20.bmp", cv2.cvtColor(im_tracer_20, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_20)
plt.show()

# %%
im_tracer_21 = im_rgb[162:182, 91:111, :]
cv2.imwrite(OUT_DIR + "tracer_21.bmp", cv2.cvtColor(im_tracer_21, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_21)
plt.show()

# %%
im_tracer_22 = im_rgb[188:208, 42:62, :]
cv2.imwrite(OUT_DIR + "tracer_22.bmp", cv2.cvtColor(im_tracer_22, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_22)
plt.show()

# %%
im_tracer_23 = im_rgb[224:244, 128:148, :]
cv2.imwrite(OUT_DIR + "tracer_23.bmp", cv2.cvtColor(im_tracer_23, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_23)
plt.show()

# %%
im_tracer_24 = im_rgb[265:285, 62:82, :]
cv2.imwrite(OUT_DIR + "tracer_24.bmp", cv2.cvtColor(im_tracer_24, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_24)
plt.show()

# %%
im_tracer_25 = im_rgb[244:264, 193:213, :]
cv2.imwrite(OUT_DIR + "tracer_25.bmp", cv2.cvtColor(im_tracer_25, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_25)
plt.show()

# %%
im_tracer_26 = im_rgb[264:284, 281:301, :]
cv2.imwrite(OUT_DIR + "tracer_26.bmp", cv2.cvtColor(im_tracer_26, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_26)
plt.show()

# %%
im_tracer_27 = im_rgb[165:185, 225:245, :]
cv2.imwrite(OUT_DIR + "tracer_27.bmp", cv2.cvtColor(im_tracer_27, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_27)
plt.show()

# %%
im_tracer_28 = im_rgb[194:214, 297:317, :]
cv2.imwrite(OUT_DIR + "tracer_28.bmp", cv2.cvtColor(im_tracer_28, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_28)
plt.show()

# %%
im_tracer_29 = im_rgb[167:187, 481:501, :]
cv2.imwrite(OUT_DIR + "tracer_29.bmp", cv2.cvtColor(im_tracer_29, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_29)
plt.show()

# %%
im_tracer_30 = im_rgb[251:271, 433:453, :]
cv2.imwrite(OUT_DIR + "tracer_30.bmp", cv2.cvtColor(im_tracer_30, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_30)
plt.show()

# %%
im_tracer_31 = im_rgb[120:140, 527:547, :]
cv2.imwrite(OUT_DIR + "tracer_31.bmp", cv2.cvtColor(im_tracer_31, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_31)
plt.show()

# %%
im_tracer_32 = im_rgb[160:180, 513:533, :]
cv2.imwrite(OUT_DIR + "tracer_32.bmp", cv2.cvtColor(im_tracer_32, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_32)
plt.show()

# %%
im_tracer_33 = im_rgb[198:218, 526:546, :]
cv2.imwrite(OUT_DIR + "tracer_33.bmp", cv2.cvtColor(im_tracer_0, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_33)
plt.show()

# %%
im_tracer_34 = im_rgb[279:299, 472:492, :]
cv2.imwrite(OUT_DIR + "tracer_34.bmp", cv2.cvtColor(im_tracer_34, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_34)
plt.show()

# %%
im_tracer_35 = im_rgb[265:285, 449:469, :]
cv2.imwrite(OUT_DIR + "tracer_35.bmp", cv2.cvtColor(im_tracer_35, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_35)
plt.show()

# %%
im_tracer_36 = im_rgb[280:300, 567:587, :]
cv2.imwrite(OUT_DIR + "tracer_36.bmp", cv2.cvtColor(im_tracer_36, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_36)
plt.show()

# %%
im_tracer_37 = im_rgb[258:278, 647:667, :]
cv2.imwrite(OUT_DIR + "tracer_37.bmp", cv2.cvtColor(im_tracer_37, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_37)
plt.show()

# %%
im_tracer_38 = im_rgb[281:301, 675:695, :]
cv2.imwrite(OUT_DIR + "tracer_38.bmp", cv2.cvtColor(im_tracer_38, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_38)
plt.show()

# %%
im_tracer_39 = im_rgb[8:28, 663:683, :]
cv2.imwrite(OUT_DIR + "tracer_39.bmp", cv2.cvtColor(im_tracer_39, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_39)
plt.show()

# %%
im_tracer_40 = im_rgb[97:117, 743:763, :]
cv2.imwrite(OUT_DIR + "tracer_40.bmp", cv2.cvtColor(im_tracer_40, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_40)
plt.show()

# %%
im_tracer_41 = im_rgb[103:123, 760:780, :]
cv2.imwrite(OUT_DIR + "tracer_41.bmp", cv2.cvtColor(im_tracer_41, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_41)
plt.show()

# %%
im_tracer_42 = im_rgb[159:179, 763:783, :]
cv2.imwrite(OUT_DIR + "tracer_42.bmp", cv2.cvtColor(im_tracer_42, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_42)
plt.show()

# %%
DIR = "adj/"
FILE = "C001H001S0003000200.bmp"
OUT_DIR = "tracer_imgs_dark/"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)

# %%
im_tracer_43 = im_rgb[147:167, 102:122, :]
cv2.imwrite(OUT_DIR + "tracer_43.bmp", cv2.cvtColor(im_tracer_43, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_43)
plt.show()

# %%
im_tracer_44 = im_rgb[223:243, 228:248, :]
cv2.imwrite(OUT_DIR + "tracer_44.bmp", cv2.cvtColor(im_tracer_44, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_44)
plt.show()

# %%
im_tracer_45 = im_rgb[159:179, 417:437, :]
cv2.imwrite(OUT_DIR + "tracer_45.bmp", cv2.cvtColor(im_tracer_45, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_45)
plt.show()

# %%
im_tracer_46 = im_rgb[187:207, 640:660, :]
cv2.imwrite(OUT_DIR + "tracer_46.bmp", cv2.cvtColor(im_tracer_46, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_46)
plt.show()

# %%
im_tracer_47 = im_rgb[55:75, 888:908, :]
cv2.imwrite(OUT_DIR + "tracer_47.bmp", cv2.cvtColor(im_tracer_47, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_47)
plt.show()

# %%
im_tracer_48 = im_rgb[266:286, 819:839, :]
cv2.imwrite(OUT_DIR + "tracer_48.bmp", cv2.cvtColor(im_tracer_48, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_48)
plt.show()

# %%
im_tracer_49 = im_rgb[744:764, 973:993, :]
cv2.imwrite(OUT_DIR + "tracer_49.bmp", cv2.cvtColor(im_tracer_49, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_49)
plt.show()

# %%
DIR = "adj/"
FILE = "C001H001S0004000200.bmp"
OUT_DIR = "tracer_imgs_dark/"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)

# %%
im_tracer_50 = im_rgb[72:92, 332:352, :]
cv2.imwrite(OUT_DIR + "tracer_50.bmp", cv2.cvtColor(im_tracer_50, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_50)
plt.show()

# %%
im_tracer_51 = im_rgb[186:206, 348:368, :]
cv2.imwrite(OUT_DIR + "tracer_51.bmp", cv2.cvtColor(im_tracer_51, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_51)
plt.show()

# %%
im_tracer_52 = im_rgb[153:173, 423:443, :]
cv2.imwrite(OUT_DIR + "tracer_52.bmp", cv2.cvtColor(im_tracer_52, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_52)
plt.show()

# %%
im_tracer_53 = im_rgb[148:168, 454:474, :]
cv2.imwrite(OUT_DIR + "tracer_53.bmp", cv2.cvtColor(im_tracer_53, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_53)
plt.show()

# %%
im_tracer_54 = im_rgb[511:531, 37:57, :]
cv2.imwrite(OUT_DIR + "tracer_54.bmp", cv2.cvtColor(im_tracer_54, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_54)
plt.show()

# %%
im_tracer_55 = im_rgb[220:240, 660:680, :]
cv2.imwrite(OUT_DIR + "tracer_55.bmp", cv2.cvtColor(im_tracer_55, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_55)
plt.show()

# %%
im_tracer_56 = im_rgb[224:244, 594:614, :]
cv2.imwrite(OUT_DIR + "tracer_56.bmp", cv2.cvtColor(im_tracer_56, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_56)
plt.show()

# %%
im_tracer_57 = im_rgb[107:127, 393:413, :]
cv2.imwrite(OUT_DIR + "tracer_57.bmp", cv2.cvtColor(im_tracer_57, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_57)
plt.show()

# %%
DIR = "adj/"
FILE = "C001H001S0005001091.bmp"
OUT_DIR = "tracer_imgs_dark/"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)

# %%
im_tracer_58 = im_rgb[41:61, 474:494, :]
cv2.imwrite(OUT_DIR + "tracer_58.bmp", cv2.cvtColor(im_tracer_58, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_58)
plt.show()

# %%
im_tracer_59 = im_rgb[75:95, 417:437, :]
cv2.imwrite(OUT_DIR + "tracer_59.bmp", cv2.cvtColor(im_tracer_59, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_59)
plt.show()

# %%
im_tracer_60 = im_rgb[122:142, 361:381, :]
cv2.imwrite(OUT_DIR + "tracer_60.bmp", cv2.cvtColor(im_tracer_60, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_60)
plt.show()

# %%
im_tracer_61 = im_rgb[258:278, 425:445, :]
cv2.imwrite(OUT_DIR + "tracer_61.bmp", cv2.cvtColor(im_tracer_61, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_61)
plt.show()

# %%
im_tracer_62 = im_rgb[226:246, 197:217, :]
cv2.imwrite(OUT_DIR + "tracer_62.bmp", cv2.cvtColor(im_tracer_62, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_62)
plt.show()

# %%
im_tracer_63 = im_rgb[731:751, 865:885, :]
cv2.imwrite(OUT_DIR + "tracer_63.bmp", cv2.cvtColor(im_tracer_63, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_63)
plt.show()

# %%
im_tracer_64 = im_rgb[713:733, 950:970, :]
cv2.imwrite(OUT_DIR + "tracer_64.bmp", cv2.cvtColor(im_tracer_64, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_64)
plt.show()

# %%
im_tracer_65 = im_rgb[219:239, 625:645, :]
cv2.imwrite(OUT_DIR + "tracer_65.bmp", cv2.cvtColor(im_tracer_65, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_65)
plt.show()

# %%
DIR = "adj/"
FILE = "C001H001S0006000116.bmp"
OUT_DIR = "tracer_imgs_dark/"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)

# %%
im_tracer_66 = im_rgb[116:136, 37:57, :]
cv2.imwrite(OUT_DIR + "tracer_66.bmp", cv2.cvtColor(im_tracer_66, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_66)
plt.show()

# %%
im_tracer_67 = im_rgb[169:189, 76:96, :]
cv2.imwrite(OUT_DIR + "tracer_67.bmp", cv2.cvtColor(im_tracer_67, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_67)
plt.show()

# %%
im_tracer_68 = im_rgb[304:324, 77:97, :]
cv2.imwrite(OUT_DIR + "tracer_68.bmp", cv2.cvtColor(im_tracer_68, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_68)
plt.show()

# %%
im_tracer_69 = im_rgb[149:169, 461:481, :]
cv2.imwrite(OUT_DIR + "tracer_69.bmp", cv2.cvtColor(im_tracer_69, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_69)
plt.show()

# %%
im_tracer_70 = im_rgb[171:191, 481:501, :]
cv2.imwrite(OUT_DIR + "tracer_70.bmp", cv2.cvtColor(im_tracer_70, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_70)
plt.show()

# %%
im_tracer_71 = im_rgb[179:199, 511:531, :]
cv2.imwrite(OUT_DIR + "tracer_71.bmp", cv2.cvtColor(im_tracer_71, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_71)
plt.show()

# %%
im_tracer_72 = im_rgb[253:273, 605:625, :]
cv2.imwrite(OUT_DIR + "tracer_72.bmp", cv2.cvtColor(im_tracer_72, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_72)
plt.show()

# %%
im_tracer_73 = im_rgb[225:245, 846:866, :]
cv2.imwrite(OUT_DIR + "tracer_73.bmp", cv2.cvtColor(im_tracer_73, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_73)
plt.show()

# %%
im_tracer_74 = im_rgb[211:231, 860:880, :]
cv2.imwrite(OUT_DIR + "tracer_74.bmp", cv2.cvtColor(im_tracer_74, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_74)
plt.show()

# %%
im_tracer_75 = im_rgb[642:662, 985:1005, :]
cv2.imwrite(OUT_DIR + "tracer_75.bmp", cv2.cvtColor(im_tracer_75, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_75)
plt.show()

# %%
DIR = "adj/"
FILE = "C001H001S0007004548.bmp"
OUT_DIR = "tracer_imgs_dark/"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)

# %%
im_tracer_76 = im_rgb[104:124, 350:370, :]
cv2.imwrite(OUT_DIR + "tracer_76.bmp", cv2.cvtColor(im_tracer_76, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_76)
plt.show()

# %%
im_tracer_77 = im_rgb[97:117, 410:430, :]
cv2.imwrite(OUT_DIR + "tracer_77.bmp", cv2.cvtColor(im_tracer_77, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_77)
plt.show()

# %%
im_tracer_78 = im_rgb[166:186, 379:399, :]
cv2.imwrite(OUT_DIR + "tracer_78.bmp", cv2.cvtColor(im_tracer_78, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_78)
plt.show()

# %%
im_tracer_79 = im_rgb[187:207, 268:288, :]
cv2.imwrite(OUT_DIR + "tracer_79.bmp", cv2.cvtColor(im_tracer_79, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_79)
plt.show()

# %%
im_tracer_80 = im_rgb[249:269, 290:310, :]
cv2.imwrite(OUT_DIR + "tracer_80.bmp", cv2.cvtColor(im_tracer_80, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_80)
plt.show()

# %%
im_tracer_81 = im_rgb[221:241, 610:630, :]
cv2.imwrite(OUT_DIR + "tracer_81.bmp", cv2.cvtColor(im_tracer_81, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_81)
plt.show()

# %%
im_tracer_82 = im_rgb[267:287, 523:543, :]
cv2.imwrite(OUT_DIR + "tracer_82.bmp", cv2.cvtColor(im_tracer_82, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_82)
plt.show()

# %%
im_tracer_83 = im_rgb[276:296, 569:589, :]
cv2.imwrite(OUT_DIR + "tracer_83.bmp", cv2.cvtColor(im_tracer_83, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_83)
plt.show()

# %%
DIR = "adj/"
FILE = "C001H001S0008000242.bmp"
OUT_DIR = "tracer_imgs_dark/"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)

# %%
im_tracer_84 = im_rgb[155:175, 55:75, :]
cv2.imwrite(OUT_DIR + "tracer_84.bmp", cv2.cvtColor(im_tracer_84, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_84)
plt.show()

# %%
im_tracer_85 = im_rgb[92:112, 165:185, :]
cv2.imwrite(OUT_DIR + "tracer_85.bmp", cv2.cvtColor(im_tracer_85, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_85)
plt.show()

# %%
im_tracer_86 = im_rgb[84:104, 490:510, :]
cv2.imwrite(OUT_DIR + "tracer_86.bmp", cv2.cvtColor(im_tracer_86, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_86)
plt.show()

# %%
im_tracer_87 = im_rgb[222:242, 262:282, :]
cv2.imwrite(OUT_DIR + "tracer_87.bmp", cv2.cvtColor(im_tracer_87, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_87)
plt.show()

# %%
im_tracer_88 = im_rgb[113:133, 402:422, :]
cv2.imwrite(OUT_DIR + "tracer_88.bmp", cv2.cvtColor(im_tracer_88, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_88)
plt.show()

# %%
im_tracer_89 = im_rgb[372:392, 25:45, :]
cv2.imwrite(OUT_DIR + "tracer_89.bmp", cv2.cvtColor(im_tracer_89, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_89)
plt.show()

# %%
im_tracer_90 = im_rgb[573:593, 955:975, :]
cv2.imwrite(OUT_DIR + "tracer_90.bmp", cv2.cvtColor(im_tracer_90, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_90)
plt.show()

# %%
im_tracer_91 = im_rgb[171:191, 270:290, :]
cv2.imwrite(OUT_DIR + "tracer_91.bmp", cv2.cvtColor(im_tracer_91, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_91)
plt.show()

# %%
im_tracer_92 = im_rgb[229:249, 107:127, :]
cv2.imwrite(OUT_DIR + "tracer_92.bmp", cv2.cvtColor(im_tracer_92, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_92)
plt.show()

# %%
im_tracer_93 = im_rgb[195:215, 60:80, :]
cv2.imwrite(OUT_DIR + "tracer_93.bmp", cv2.cvtColor(im_tracer_93, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_93)
plt.show()

# %%
DIR = "adj/"
FILE = "C001H001S0009001207.bmp"
OUT_DIR = "tracer_imgs_dark/"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)

# %%
im_tracer_94 = im_rgb[155:175, 444:464, :]
cv2.imwrite(OUT_DIR + "tracer_94.bmp", cv2.cvtColor(im_tracer_94, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_94)
plt.show()

# %%
im_tracer_95 = im_rgb[64:84, 600:620, :]
cv2.imwrite(OUT_DIR + "tracer_95.bmp", cv2.cvtColor(im_tracer_95, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_95)
plt.show()

# %%
im_tracer_96 = im_rgb[161:181, 929:949, :]
cv2.imwrite(OUT_DIR + "tracer_96.bmp", cv2.cvtColor(im_tracer_96, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_96)
plt.show()

# %%
im_tracer_97 = im_rgb[262:282, 235:255, :]
cv2.imwrite(OUT_DIR + "tracer_97.bmp", cv2.cvtColor(im_tracer_97, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_97)
plt.show()

# %%
im_tracer_98 = im_rgb[340:360, 879:899, :]
cv2.imwrite(OUT_DIR + "tracer_98.bmp", cv2.cvtColor(im_tracer_98, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_98)
plt.show()

# %%
DIR = "adj/"
FILE = "C001H001S0010001292.bmp"
OUT_DIR = "tracer_imgs_dark/"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)

# %%
im_tracer_99 = im_rgb[170:190, 161:181, :]
cv2.imwrite(OUT_DIR + "tracer_99.bmp", cv2.cvtColor(im_tracer_99, cv2.COLOR_RGB2BGR))

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_99)
plt.show()

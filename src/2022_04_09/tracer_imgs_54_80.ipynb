# %%
import os

import cv2
import matplotlib.pyplot as plt

# %%
user = os.environ["USER"]
SUPER_DIR = f"/media/{user}/ボリューム1/M2/original/2022_04_09/"

# %%
DIR = SUPER_DIR + "cbi_q_1/C001H001S0003/"
FILE = "C001H001S0003003601.bmp"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = im_bgr[:, :, [2, 1, 0]]

# %%
plt.figure(figsize=(16, 16))
plt.imshow(im_rgb)
plt.show()

# %%
im_tracer_54 = im_rgb[375:395, 552:572, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_54)
plt.show()

# %%
im_tracer_55 = im_rgb[413:433, 592:612, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_55)
plt.show()

# %%
im_tracer_56 = im_rgb[411:431, 674:694, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_56)
plt.show()

# %%
im_tracer_57 = im_rgb[471:491, 214:234, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_57)
plt.show()

# %%
im_tracer_58 = im_rgb[493:513, 582:602, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_58)
plt.show()

# %%
im_tracer_59 = im_rgb[506:526, 644:664, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_59)
plt.show()

# %%
im_tracer_60 = im_rgb[471:491, 743:763, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_60)
plt.show()

# %%
im_tracer_61 = im_rgb[538:558, 322:342, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_61)
plt.show()

# %%
im_tracer_62 = im_rgb[535:555, 664:684, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_62)
plt.show()

# %%
im_tracer_63 = im_rgb[513:533, 783:803, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_63)
plt.show()

# %%
im_tracer_64 = im_rgb[592:612, 510:530, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_64)
plt.show()

# %%
im_tracer_65 = im_rgb[662:682, 734:754, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_65)
plt.show()

# %%
im_tracer_66 = im_rgb[794:814, 215:235, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_66)
plt.show()

# %%
im_tracer_67 = im_rgb[795:815, 531:551, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_67)
plt.show()

# %%
im_tracer_68 = im_rgb[751:771, 702:722, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_68)
plt.show()

# %%
im_tracer_69 = im_rgb[862:882, 273:293, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_69)
plt.show()

# %%
im_tracer_70 = im_rgb[853:873, 320:340, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_70)
plt.show()

# %%
im_tracer_71 = im_rgb[819:839, 512:532, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_71)
plt.show()

# %%
im_tracer_72 = im_rgb[814:834, 556:576, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_72)
plt.show()

# %%
im_tracer_73 = im_rgb[827:847, 599:619, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_73)
plt.show()

# %%
im_tracer_74 = im_rgb[795:815, 680:700, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_74)
plt.show()

# %%
im_tracer_75 = im_rgb[809:829, 722:742, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_75)
plt.show()

# %%
im_tracer_76 = im_rgb[781:801, 788:808, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_76)
plt.show()

# %%
im_tracer_77 = im_rgb[875:895, 148:168, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_77)
plt.show()

# %%
im_tracer_78 = im_rgb[848:868, 729:749, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_78)
plt.show()

# %%
im_tracer_79 = im_rgb[839:859, 790:810, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_79)
plt.show()

# %%
im_tracer_80 = im_rgb[878:898, 750:770, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_80)
plt.show()

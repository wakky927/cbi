# %%
import os

import cv2
import matplotlib.pyplot as plt

# %%
user = os.environ["USER"]
SUPER_DIR = f"/media/{user}/ボリューム1/M2/original/2022_04_09/"

# %%
# DIR = SUPER_DIR + "cbi_q_1/C001H001S0004/"
# FILE = "C001H001S0004003701.bmp"
DIR = "samples/"
FILE = "C001H001S0004003701.png"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = im_bgr[:, :, [2, 1, 0]]

# %%
plt.figure(figsize=(16, 16))
plt.imshow(im_rgb)
plt.show()

# %%
im_tracer_81 = im_rgb[346:366, 120:140, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_81)
plt.show()

# %%
im_tracer_82 = im_rgb[353:373, 159:179, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_82)
plt.show()

# %%
im_tracer_83 = im_rgb[337:357, 728:748, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_83)
plt.show()

# %%
im_tracer_84 = im_rgb[393:413, 506:526, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_84)
plt.show()

# %%
im_tracer_85 = im_rgb[463:483, 408:428, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_85)
plt.show()

# %%
im_tracer_86 = im_rgb[489:509, 458:478, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_86)
plt.show()

# %%
im_tracer_87 = im_rgb[468:488, 637:657, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_87)
plt.show()

# %%
im_tracer_88 = im_rgb[515:535, 566:586, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_88)
plt.show()

# %%
im_tracer_89 = im_rgb[525:545, 600:620, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_89)
plt.show()

# %%
im_tracer_90 = im_rgb[517:537, 630:650, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_90)
plt.show()

# %%
im_tracer_91 = im_rgb[501:521, 646:666, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_91)
plt.show()

# %%
im_tracer_92 = im_rgb[586:606, 330:350, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_92)
plt.show()

# %%
im_tracer_93 = im_rgb[605:625, 752:772, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_93)
plt.show()

# %%
im_tracer_94 = im_rgb[631:651, 410:430, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_94)
plt.show()

# %%
im_tracer_95 = im_rgb[632:652, 602:622, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_95)
plt.show()

# %%
im_tracer_96 = im_rgb[722:742, 223:243, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_96)
plt.show()

# %%
im_tracer_97 = im_rgb[710:730, 448:468, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_97)
plt.show()

# %%
im_tracer_99 = im_rgb[755:775, 395:415, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_99)
plt.show()

# %%
im_tracer_100 = im_rgb[746:766, 618:638, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_100)
plt.show()

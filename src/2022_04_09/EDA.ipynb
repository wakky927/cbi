# %%
import copy
import os

import cv2
import matplotlib.pyplot as plt

# %%
user = os.environ["USER"]
SUPER_DIR = f"/media/{user}/ボリューム1/M2/original/2022_04_09/"

# %%
# DIR = SUPER_DIR + "cbi_q_1/C001H001S0001/"
# FILE = "C001H001S0001000101.bmp"
# DIR = "samples/"
# FILE = "C001H001S0004003701.png"
DIR = "adj/"
FILE = "C001H001S0001001500.bmp"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = im_bgr[:, :, [2, 1, 0]]

# %%
plt.figure(figsize=(16, 16))
plt.imshow(im_rgb)
plt.show()

# %%
im = copy.deepcopy(im_rgb)
im[0:310, :, 0] = 200
im[290:800, 0:110, 1] = 200
im[290:800, 800:, 2] = 200

# %%
plt.figure(figsize=(16, 16))
plt.imshow(im)
plt.show()

# %%
im_tracer = im_rgb[409:429, 383:403, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer)
plt.show()

# %%
FILE = "C001H001S0001003001.bmp"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = im_bgr[:, :, [2, 1, 0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/75/dz10lh0n0yj1snrsvfbf3_9m0000gn/T/ipykernel_6477/3057769514.py in <module>
#       2
#       3 im_bgr = cv2.imread(DIR + FILE)
# ----> 4 im_rgb = im_bgr[:, :, [2, 1, 0]]
#
# TypeError: 'NoneType' object is not subscriptable

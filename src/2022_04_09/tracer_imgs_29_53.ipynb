# %%
import os

import cv2
import matplotlib.pyplot as plt

# %%
user = os.environ["USER"]
SUPER_DIR = f"/media/{user}/ボリューム1/M2/original/2022_04_09/"

# %%
DIR = SUPER_DIR + "cbi_q_1/C001H001S0002/"
FILE = "C001H001S0002003501.bmp"

im_bgr = cv2.imread(DIR + FILE)
im_rgb = im_bgr[:, :, [2, 1, 0]]

# %%
plt.figure(figsize=(16, 16))
plt.imshow(im_rgb)
plt.show()

# %%
im_tracer_29 = im_rgb[360:380, 208:228, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_29)
plt.show()

# %%
im_tracer_30 = im_rgb[349:369, 357:377, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_30)
plt.show()

# %%
im_tracer_31 = im_rgb[328:348, 446:466, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_31)
plt.show()

# %%
im_tracer_32 = im_rgb[385:405, 624:644, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_32)
plt.show()

# %%
im_tracer_33 = im_rgb[428:448, 142:162, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_33)
plt.show()

# %%
im_tracer_34 = im_rgb[449:469, 154:174, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_34)
plt.show()

# %%
im_tracer_35 = im_rgb[481:501, 126:146, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_35)
plt.show()

# %%
im_tracer_36 = im_rgb[484:504, 144:164, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_36)
plt.show()

# %%
im_tracer_37 = im_rgb[444:464, 361:381, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_37)
plt.show()

# %%
im_tracer_38 = im_rgb[426:446, 387:407, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_38)
plt.show()

# %%
im_tracer_39 = im_rgb[595:615, 759:779, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_39)
plt.show()

# %%
im_tracer_40 = im_rgb[674:694, 463:483, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_40)
plt.show()

# %%
im_tracer_41 = im_rgb[666:686, 727:747, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_41)
plt.show()

# %%
im_tracer_42 = im_rgb[653:673, 782:802, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_42)
plt.show()

# %%
im_tracer_43 = im_rgb[701:721, 770:790, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_43)
plt.show()

# %%
im_tracer_44 = im_rgb[730:750, 143:163, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_44)
plt.show()

# %%
im_tracer_45 = im_rgb[727:747, 419:439, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_45)
plt.show()

# %%
im_tracer_46 = im_rgb[732:752, 486:506, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_46)
plt.show()

# %%
im_tracer_47 = im_rgb[730:750, 546:566, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_47)
plt.show()

# %%
im_tracer_48 = im_rgb[724:744, 565:585, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_48)
plt.show()

# %%
im_tracer_49 = im_rgb[739:759, 561:581, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_49)
plt.show()

# %%
im_tracer_50 = im_rgb[782:802, 322:342, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_50)
plt.show()

# %%
im_tracer_51 = im_rgb[844:864, 272:292, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_51)
plt.show()

# %%
im_tracer_52 = im_rgb[819:839, 797:817, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_52)
plt.show()

# %%
im_tracer_53 = im_rgb[920:940, 474:494, :]

plt.figure(figsize=(4, 4))
plt.imshow(im_tracer_53)
plt.show()
